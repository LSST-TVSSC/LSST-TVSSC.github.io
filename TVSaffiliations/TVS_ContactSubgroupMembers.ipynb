# %% [markdown]
# <a href="https://colab.research.google.com/github/LSST-TVSSC/LSST-TVSSC.github.io/blob/master/TVSaffiliations/TVS_ContactSubgroupMembers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#just prints the emails of members of a group 
#both primary and secondary members

'__author__' == 'Federica Bianco, UDel - GitHub: fedhere'
import sys
import pandas as pd
import numpy as np
tvsfile = '1Q8YPGxh-Ebs02ykfGypj7oThQrgqKzrU6qyIuPT3bhY'

# %%
sbuglist = ['']

TVSMembers = pd.read_csv('https://docs.google.com/spreadsheets/d/' +
                             tvsfile +
                             '/export?gid=0&format=csv')
TVSMembers.rename({"Unnamed: 0":"last name"}, axis=1, inplace=True)
#only select members that signed the CoC
TVSMembers = TVSMembers.loc[~TVSMembers["signed CoC"].isna()]
TVSMembers.head()
# Out:
#   last name first name                                        affiliation  \
# 0    Abrams    Natasha                                 Harvard University
# 1    Ackley    Kendall                                  Monash University
# 2  Adhikari    Susmita  Indian Institute of Science Education and Rese...
# 3      Agol       Eric                           University of Washington
# 4      Aleo    Patrick         University of Illinois at Urbana-Champaign
#
#   continent                      email                 signed CoC  Unnamed: 6  \
# 0        US      nsabrams@berkeley.edu      nsabrams@berkeley.edu        True
# 1        AU  kendall.ackley@monash.edu  kendall.ackley@monash.edu        True
# 2     India    susmita@iiserpune.ac.in    susmita@iiserpune.ac.in        True
# 3        US  agol@astro.washington.edu  agol@astro.washington.edu        True
# 4        US        paleo2@illinois.edu        paleo2@illinois.edu        True
#
#                                          primary  \
# 0                                   Microlensing
# 1  Multiwavelength Characterization/Counterparts
# 2  Multiwavelength Characterization/Counterparts
# 3                                   Microlensing
# 4                                     Supernovae
#
#                          secondary      secondary.1          secondary.2  \
# 0                              NaN              NaN                  NaN
# 1  Classification/Characterization  Fast Transients                  NaN
# 2  Classification/Characterization              NaN                  NaN
# 3                              NaN              NaN                  NaN
# 4  Classification/Characterization  Fast Transients  Pulsating Variables
#
#   Unnamed: 11 Unnamed: 12  date added  added by
# 0         NaN         NaN         NaN       NaN
# 1         NaN         NaN         NaN       NaN
# 2         NaN         NaN         NaN       NaN
# 3         NaN         NaN         NaN       NaN
# 4         NaN         NaN         NaN       NaN

# %%
#create the list of all subgroups in TVS
subgroups = (np.concatenate([TVSMembers.primary.unique(), 
                                     TVSMembers["secondary"].unique(), 
            TVSMembers["secondary.1"].unique(), 
            TVSMembers["secondary.2"].unique()]))

subgroups = list(sorted(set([s for s in subgroups if not isinstance(s, float)])))
subgroups
# Out:
# ['Anomalies and true novelties',
#  'Blazars',
#  'Classification/Characterization',
#  'Cosmological',
#  'Data Visualizations & Representations',
#  'Distance Scales',
#  'Fast Transients',
#  'Galactic',
#  'Interacting Binaries',
#  'LSST',
#  'Magnetically Active Stars',
#  'Microlensing',
#  'Multiwavelength Characterization/Counterparts',
#  'Non-degenerate Eruptive Variables',
#  'Pulsating Variables',
#  'Supernovae',
#  'Tidal Disruption Events',
#  'Transiting Planets']

# %%
import ipywidgets as widgets
from IPython.display import display
from IPython.html.widgets import interactive
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
def alllist(x):
  print("subgroup selected:", x)
  # PRIMARY or SECONDARY
  emails = TVSMembers[(TVSMembers["primary"] == x) |
                      (TVSMembers["secondary"] == x) | 
                      (TVSMembers["secondary.1"] == x) | 
                      (TVSMembers["secondary.2"] == x)]['signed CoC'].values
  print(emails)
  return x

w = widgets.Select(options=subgroups)
interactive(alllist, x=w)
# Out:
# interactive(children=(Select(description='x', options=('Anomalies and true novelties', 'Blazars', 'Classificat…

# %%
def primarylist(x):
  print("primary selected:", x)
  # PRIMARY
  emails = TVSMembers[TVSMembers.primary == x]['signed CoC'].values
  print(emails)
  return x

w = widgets.Select(options=subgroups)
interactive(primarylist, x=w)
# Out:
# interactive(children=(Select(description='x', options=('Anomalies and true novelties', 'Blazars', 'Classificat…

# %%
def secondarylist(x):
  print("secondary selected:", x)
  # SECONDARY
  emails = TVSMembers[TVSMembers.secondary == x]['signed CoC'].values
  print(emails)
  return x

w = widgets.Select(options=subgroups)
interactive(secondarylist, x=w)
# Out:
# interactive(children=(Select(description='x', options=('Anomalies and true novelties', 'Blazars', 'Classificat…
